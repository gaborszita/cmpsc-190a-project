# %%
import pandas as pd
import time
import random
import os
from nba_api.stats.endpoints import leaguegamelog, boxscoretraditionalv2

pd.set_option('display.max_columns', None)

# %%
# === Config ===
SEASONS = ['2024-25']
CSV_PATH = 'nba_boxscores.csv'

def smart_sleep(min_sec=1.2, max_sec=3.5):
    time.sleep(random.uniform(min_sec, max_sec))

# %%
def get_existing_game_ids(csv_path):
    if os.path.exists(csv_path):
        existing = pd.read_csv(csv_path, usecols=['GAME_ID'], dtype={'GAME_ID': str})
        return set(existing['GAME_ID'].unique())
    return set()

def get_all_game_ids_and_dates(season):
    all_games = []
    season_types = ['Regular Season', 'Playoffs']

    for season_type in season_types:
        print(f"📅 Fetching {season_type} logs for {season}")
        gamelog = leaguegamelog.LeagueGameLog(
            season=season,
            player_or_team_abbreviation='T',
            season_type_all_star=season_type
        )
        df = gamelog.get_data_frames()[0]
        df = df[['GAME_ID', 'GAME_DATE']]
        df['SEASON'] = season
        df['SEASON_TYPE'] = season_type
        df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
        all_games.append(df)
        smart_sleep()

    combined = pd.concat(all_games, ignore_index=True)
    combined = combined.drop_duplicates(subset='GAME_ID')
    return combined

def fetch_box_score(game_id):
    box = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id)
    player_df = box.get_data_frames()[0]
    player_df['GAME_ID'] = game_id

    # Load team-level stats
    team_df = box.team_stats.get_data_frame()
    team_df = team_df.drop(['GAME_ID', 'TEAM_NAME', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'MIN'], axis=1)
    team_df = team_df.add_prefix('TEAM_')  # Prevent column collisions during merge
    team_df = team_df.rename(columns={'TEAM_TEAM_ID': 'TEAM_ID'})  # Rename back for joining

    # Merge team stats into player stats
    merged_df = player_df.merge(team_df, on='TEAM_ID', how='left')

    # Determine home and away teams
    team_ids = merged_df['TEAM_ID'].drop_duplicates().tolist()
    if len(team_ids) != 2:
        print(f"⚠️ Unexpected number of teams in GAME_ID {game_id}")
        return None

    away_team_id, home_team_id = team_ids
    away_score = merged_df.loc[merged_df['TEAM_ID'] == away_team_id, 'TEAM_PTS'].values[0]
    home_score = merged_df.loc[merged_df['TEAM_ID'] == home_team_id, 'TEAM_PTS'].values[0]

    # Add indicators
    merged_df['HOME'] = merged_df['TEAM_ID'] == home_team_id
    merged_df['AWAY'] = merged_df['TEAM_ID'] == away_team_id
    winning_team_id = home_team_id if home_score > away_score else away_team_id
    merged_df['WON'] = merged_df['TEAM_ID'] == winning_team_id
    merged_df['FINAL_SCORE'] = merged_df.apply(
        lambda row: [int(home_score), int(away_score)] if row['TEAM_ID'] == home_team_id else [int(away_score), int(home_score)],
        axis=1
    )

    return merged_df

def main(season):
    csv_path = f"data/nba_boxscores_{season}.csv"

    print("🔍 Checking existing data...")
    existing_game_ids = get_existing_game_ids(csv_path)

    print("📅 Getting game IDs + dates for seasons...")
    games_df = get_all_game_ids_and_dates(season)
    new_games = games_df[~games_df['GAME_ID'].isin(existing_game_ids)]
    new_games = new_games.reset_index(drop=True)

    print(f"🆕 Found {len(new_games)} new games to fetch.")

    for i, row in new_games.iterrows():
        game_id = row['GAME_ID']
        game_date = row['GAME_DATE']
        game_type = row['SEASON_TYPE']

        try:
            print(f"📦 Fetching box score for {game_id} ({game_date.date()}) [{i+1}/{len(new_games)}]")
            df = fetch_box_score(game_id)
            df['GAME_DATE'] = game_date
            df['SEASON_TYPE'] = game_type

            if os.path.exists(csv_path):
                df.to_csv(csv_path, mode='a', header=False, index=False)
            else:
                df.to_csv(csv_path, index=False)

            smart_sleep()
        except Exception as e:
            print(f"❌ Error fetching {game_id}: {e}")
            continue

# %%
main('2024-25')
# Out:
# 🔍 Checking existing data...
# 📅 Getting game IDs + dates for seasons...
# 📅 Fetching Regular Season logs for 2024-25
# 📅 Fetching Playoffs logs for 2024-25
# 🆕 Found 1077 new games to fetch.
# 📦 Fetching box score for 0022400004 (2024-11-12) [1/1077]
# 📦 Fetching box score for 0022400220 (2024-11-13) [2/1077]
# 📦 Fetching box score for 0022400219 (2024-11-13) [3/1077]
# 📦 Fetching box score for 0022400218 (2024-11-13) [4/1077]
# 📦 Fetching box score for 0022400222 (2024-11-13) [5/1077]
# 📦 Fetching box score for 0022400223 (2024-11-13) [6/1077]
# 📦 Fetching box score for 0022400224 (2024-11-13) [7/1077]
# 📦 Fetching box score for 0022400226 (2024-11-13) [8/1077]
# 📦 Fetching box score for 0022400227 (2024-11-13) [9/1077]
# 📦 Fetching box score for 0022400225 (2024-11-13) [10/1077]
# 📦 Fetching box score for 0022400221 (2024-11-13) [11/1077]
# 📦 Fetching box score for 0022400217 (2024-11-13) [12/1077]
# 📦 Fetching box score for 0022400228 (2024-11-14) [13/1077]
# 📦 Fetching box score for 0022400009 (2024-11-15) [14/1077]
# 📦 Fetching box score for 0022400012 (2024-11-15) [15/1077]
# 📦 Fetching box score for 0022400019 (2024-11-15) [16/1077]
# 📦 Fetching box score for 0022400011 (2024-11-15) [17/1077]
# 📦 Fetching box score for 0022400018 (2024-11-15) [18/1077]
# 📦 Fetching box score for 0022400013 (2024-11-15) [19/1077]
# 📦 Fetching box score for 0022400020 (2024-11-15) [20/1077]
# 📦 Fetching box score for 0022400016 (2024-11-15) [21/1077]
# 📦 Fetching box score for 0022400014 (2024-11-15) [22/1077]
# 📦 Fetching box score for 0022400010 (2024-11-15) [23/1077]
# 📦 Fetching box score for 0022400017 (2024-11-15) [24/1077]
# 📦 Fetching box score for 0022400015 (2024-11-15) [25/1077]
# 📦 Fetching box score for 0022400229 (2024-11-16) [26/1077]
# 📦 Fetching box score for 0022400233 (2024-11-16) [27/1077]
# 📦 Fetching box score for 0022400230 (2024-11-16) [28/1077]
# 📦 Fetching box score for 0022400231 (2024-11-16) [29/1077]
# 📦 Fetching box score for 0022400232 (2024-11-16) [30/1077]
# 📦 Fetching box score for 0022400241 (2024-11-17) [31/1077]
# 📦 Fetching box score for 0022400239 (2024-11-17) [32/1077]
# 📦 Fetching box score for 0022400237 (2024-11-17) [33/1077]
# 📦 Fetching box score for 0022400235 (2024-11-17) [34/1077]
# 📦 Fetching box score for 0022400238 (2024-11-17) [35/1077]
# 📦 Fetching box score for 0022400234 (2024-11-17) [36/1077]
# 📦 Fetching box score for 0022400236 (2024-11-17) [37/1077]
# 📦 Fetching box score for 0022400243 (2024-11-17) [38/1077]
# 📦 Fetching box score for 0022400240 (2024-11-17) [39/1077]
# 📦 Fetching box score for 0022400242 (2024-11-17) [40/1077]
# 📦 Fetching box score for 0022400244 (2024-11-18) [41/1077]
# 📦 Fetching box score for 0022400246 (2024-11-18) [42/1077]
# 📦 Fetching box score for 0022400247 (2024-11-18) [43/1077]
# 📦 Fetching box score for 0022400245 (2024-11-18) [44/1077]
# 📦 Fetching box score for 0022400248 (2024-11-18) [45/1077]
# 📦 Fetching box score for 0022400250 (2024-11-18) [46/1077]
# 📦 Fetching box score for 0022400251 (2024-11-18) [47/1077]
# 📦 Fetching box score for 0022400249 (2024-11-18) [48/1077]
# 📦 Fetching box score for 0022400024 (2024-11-19) [49/1077]
# 📦 Fetching box score for 0022400021 (2024-11-19) [50/1077]
# 📦 Fetching box score for 0022400022 (2024-11-19) [51/1077]
# 📦 Fetching box score for 0022400023 (2024-11-19) [52/1077]
# 📦 Fetching box score for 0022400026 (2024-11-19) [53/1077]
# 📦 Fetching box score for 0022400025 (2024-11-19) [54/1077]
# 📦 Fetching box score for 0022400252 (2024-11-20) [55/1077]
# 📦 Fetching box score for 0022400258 (2024-11-20) [56/1077]
# 📦 Fetching box score for 0022400259 (2024-11-20) [57/1077]
# 📦 Fetching box score for 0022400257 (2024-11-20) [58/1077]
# 📦 Fetching box score for 0022400254 (2024-11-20) [59/1077]
# 📦 Fetching box score for 0022400253 (2024-11-20) [60/1077]
# 📦 Fetching box score for 0022400255 (2024-11-20) [61/1077]
# 📦 Fetching box score for 0022400256 (2024-11-20) [62/1077]
# 📦 Fetching box score for 0022400260 (2024-11-21) [63/1077]
# 📦 Fetching box score for 0022400263 (2024-11-21) [64/1077]
# 📦 Fetching box score for 0022400261 (2024-11-21) [65/1077]
# 📦 Fetching box score for 0022400262 (2024-11-21) [66/1077]
# 📦 Fetching box score for 0022400034 (2024-11-22) [67/1077]
# 📦 Fetching box score for 0022400033 (2024-11-22) [68/1077]
# 📦 Fetching box score for 0022400032 (2024-11-22) [69/1077]
# 📦 Fetching box score for 0022400029 (2024-11-22) [70/1077]
# 📦 Fetching box score for 0022400030 (2024-11-22) [71/1077]
# 📦 Fetching box score for 0022400031 (2024-11-22) [72/1077]
# 📦 Fetching box score for 0022400027 (2024-11-22) [73/1077]
# 📦 Fetching box score for 0022400028 (2024-11-22) [74/1077]
# 📦 Fetching box score for 0022400266 (2024-11-23) [75/1077]
# 📦 Fetching box score for 0022400268 (2024-11-23) [76/1077]
# 📦 Fetching box score for 0022400265 (2024-11-23) [77/1077]
# 📦 Fetching box score for 0022400267 (2024-11-23) [78/1077]
# 📦 Fetching box score for 0022400270 (2024-11-23) [79/1077]
# 📦 Fetching box score for 0022400264 (2024-11-23) [80/1077]
# 📦 Fetching box score for 0022400269 (2024-11-23) [81/1077]
# 📦 Fetching box score for 0022400272 (2024-11-24) [82/1077]
# 📦 Fetching box score for 0022400271 (2024-11-24) [83/1077]
# 📦 Fetching box score for 0022400273 (2024-11-24) [84/1077]
# 📦 Fetching box score for 0022400275 (2024-11-24) [85/1077]
# 📦 Fetching box score for 0022400276 (2024-11-24) [86/1077]
# 📦 Fetching box score for 0022400274 (2024-11-24) [87/1077]
# 📦 Fetching box score for 0022400283 (2024-11-25) [88/1077]
# 📦 Fetching box score for 0022400280 (2024-11-25) [89/1077]
# 📦 Fetching box score for 0022400281 (2024-11-25) [90/1077]
# 📦 Fetching box score for 0022400279 (2024-11-25) [91/1077]
# 📦 Fetching box score for 0022400277 (2024-11-25) [92/1077]
# 📦 Fetching box score for 0022400285 (2024-11-25) [93/1077]
# 📦 Fetching box score for 0022400284 (2024-11-25) [94/1077]
# 📦 Fetching box score for 0022400278 (2024-11-25) [95/1077]
# 📦 Fetching box score for 0022400282 (2024-11-25) [96/1077]
# 📦 Fetching box score for 0022400035 (2024-11-26) [97/1077]
# 📦 Fetching box score for 0022400036 (2024-11-26) [98/1077]
# 📦 Fetching box score for 0022400039 (2024-11-26) [99/1077]
# 📦 Fetching box score for 0022400037 (2024-11-26) [100/1077]
# 📦 Fetching box score for 0022400038 (2024-11-26) [101/1077]
# 📦 Fetching box score for 0022400288 (2024-11-27) [102/1077]
# 📦 Fetching box score for 0022400291 (2024-11-27) [103/1077]
# 📦 Fetching box score for 0022400287 (2024-11-27) [104/1077]
# 📦 Fetching box score for 0022400286 (2024-11-27) [105/1077]
# 📦 Fetching box score for 0022400289 (2024-11-27) [106/1077]
# 📦 Fetching box score for 0022400293 (2024-11-27) [107/1077]
# 📦 Fetching box score for 0022400294 (2024-11-27) [108/1077]
# 📦 Fetching box score for 0022400296 (2024-11-27) [109/1077]
# 📦 Fetching box score for 0022400290 (2024-11-27) [110/1077]
# 📦 Fetching box score for 0022400298 (2024-11-27) [111/1077]
# 📦 Fetching box score for 0022400295 (2024-11-27) [112/1077]
# 📦 Fetching box score for 0022400292 (2024-11-27) [113/1077]
# 📦 Fetching box score for 0022400297 (2024-11-27) [114/1077]
# 📦 Fetching box score for 0022400299 (2024-11-27) [115/1077]
# 📦 Fetching box score for 0022400049 (2024-11-29) [116/1077]
# 📦 Fetching box score for 0022400042 (2024-11-29) [117/1077]
# 📦 Fetching box score for 0022400041 (2024-11-29) [118/1077]
# 📦 Fetching box score for 0022400043 (2024-11-29) [119/1077]
# 📦 Fetching box score for 0022400040 (2024-11-29) [120/1077]
# 📦 Fetching box score for 0022400048 (2024-11-29) [121/1077]
# 📦 Fetching box score for 0022400046 (2024-11-29) [122/1077]
# 📦 Fetching box score for 0022400044 (2024-11-29) [123/1077]
# 📦 Fetching box score for 0022400047 (2024-11-29) [124/1077]
# 📦 Fetching box score for 0022400045 (2024-11-29) [125/1077]
# 📦 Fetching box score for 0022400304 (2024-11-30) [126/1077]
# 📦 Fetching box score for 0022400303 (2024-11-30) [127/1077]
# 📦 Fetching box score for 0022400302 (2024-11-30) [128/1077]
# 📦 Fetching box score for 0022400301 (2024-11-30) [129/1077]
# 📦 Fetching box score for 0022400300 (2024-11-30) [130/1077]
# 📦 Fetching box score for 0022400307 (2024-12-01) [131/1077]
# 📦 Fetching box score for 0022400305 (2024-12-01) [132/1077]
# 📦 Fetching box score for 0022400306 (2024-12-01) [133/1077]
# 📦 Fetching box score for 0022400308 (2024-12-01) [134/1077]
# 📦 Fetching box score for 0022400309 (2024-12-01) [135/1077]
# 📦 Fetching box score for 0022400314 (2024-12-01) [136/1077]
# 📦 Fetching box score for 0022400313 (2024-12-01) [137/1077]
# 📦 Fetching box score for 0022400312 (2024-12-01) [138/1077]
# 📦 Fetching box score for 0022400311 (2024-12-01) [139/1077]
# 📦 Fetching box score for 0022400310 (2024-12-01) [140/1077]
# 📦 Fetching box score for 0022400316 (2024-12-02) [141/1077]
# 📦 Fetching box score for 0022400318 (2024-12-02) [142/1077]
# 📦 Fetching box score for 0022400317 (2024-12-02) [143/1077]
# 📦 Fetching box score for 0022400315 (2024-12-02) [144/1077]
# 📦 Fetching box score for 0022400060 (2024-12-03) [145/1077]
# 📦 Fetching box score for 0022400059 (2024-12-03) [146/1077]
# 📦 Fetching box score for 0022400058 (2024-12-03) [147/1077]
# 📦 Fetching box score for 0022400057 (2024-12-03) [148/1077]
# 📦 Fetching box score for 0022400056 (2024-12-03) [149/1077]
# 📦 Fetching box score for 0022400054 (2024-12-03) [150/1077]
# 📦 Fetching box score for 0022400053 (2024-12-03) [151/1077]
# 📦 Fetching box score for 0022400055 (2024-12-03) [152/1077]
# 📦 Fetching box score for 0022400050 (2024-12-03) [153/1077]
# 📦 Fetching box score for 0022400051 (2024-12-03) [154/1077]
# 📦 Fetching box score for 0022400052 (2024-12-03) [155/1077]
# 📦 Fetching box score for 0022400319 (2024-12-04) [156/1077]
# 📦 Fetching box score for 0022400320 (2024-12-04) [157/1077]
# 📦 Fetching box score for 0022400322 (2024-12-04) [158/1077]
# 📦 Fetching box score for 0022400324 (2024-12-04) [159/1077]
# 📦 Fetching box score for 0022400323 (2024-12-04) [160/1077]
# 📦 Fetching box score for 0022400321 (2024-12-04) [161/1077]
# 📦 Fetching box score for 0022400331 (2024-12-05) [162/1077]
# 📦 Fetching box score for 0022400332 (2024-12-05) [163/1077]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 main('2024-25')
#
# Cell In[3], line 95, in main(season)
#      92     else:
#      93         df.to_csv(csv_path, index=False)
# ---> 95     smart_sleep()
#      96 except Exception as e:
#      97     print(f"❌ Error fetching {game_id}: {e}")
#
# Cell In[2], line 6, in smart_sleep(min_sec, max_sec)
#       5 def smart_sleep(min_sec=1.2, max_sec=3.5):
# ----> 6     time.sleep(random.uniform(min_sec, max_sec))
#
# KeyboardInterrupt:
