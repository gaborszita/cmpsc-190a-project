# %%
import pandas as pd
import time
import random
import os
from nba_api.stats.endpoints import leaguegamelog, boxscoretraditionalv2

pd.set_option('display.max_columns', None)

# %%
# === Config ===
SEASONS = ['2024-25']
CSV_PATH = 'nba_boxscores.csv'

def smart_sleep(min_sec=1.2, max_sec=3.5):
    time.sleep(random.uniform(min_sec, max_sec))

# %%
def get_existing_game_ids(csv_path):
    if os.path.exists(csv_path):
        existing = pd.read_csv(csv_path, usecols=['GAME_ID'], dtype={'GAME_ID': str})
        return set(existing['GAME_ID'].unique())
    return set()

def get_all_game_ids_and_dates(season):
    all_games = []
    season_types = ['Regular Season', 'Playoffs']

    for season_type in season_types:
        print(f"📅 Fetching {season_type} logs for {season}")
        gamelog = leaguegamelog.LeagueGameLog(
            season=season,
            player_or_team_abbreviation='T',
            season_type_all_star=season_type
        )
        df = gamelog.get_data_frames()[0]
        df = df[['GAME_ID', 'GAME_DATE']]
        df['SEASON'] = season
        df['SEASON_TYPE'] = season_type
        df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
        all_games.append(df)
        smart_sleep()

    combined = pd.concat(all_games, ignore_index=True)
    combined = combined.drop_duplicates(subset='GAME_ID')
    return combined

def fetch_box_score(game_id):
    # Load boxscores
    box = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id)
    player_df = box.get_data_frames()[0]
    team_df = box.team_stats.get_data_frame()

    # Load team-level stats
    team_df = team_df.drop(['GAME_ID', 'TEAM_NAME', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'MIN'], axis=1)
    team_df = team_df.add_prefix('TEAM_')
    team_df = team_df.rename(columns={'TEAM_TEAM_ID': 'TEAM_ID'})

    # Create opponent version of the team stats
    team_df_opp = team_df.copy()
    team_df_opp = team_df_opp.add_prefix('OPP_')

    # Merge team stats into player stats
    merged_df = player_df.merge(team_df, on='TEAM_ID', how='left')

    # Determine home and away team IDs
    team_ids = merged_df['TEAM_ID'].drop_duplicates().tolist()
    if len(team_ids) != 2:
        print(f"⚠️ Unexpected number of teams in GAME_ID {game_id}")
        return None
    away_team_id, home_team_id = team_ids

    # Get home vs. away scores
    away_score = merged_df.loc[merged_df['TEAM_ID'] == away_team_id, 'TEAM_PTS'].values[0]
    home_score = merged_df.loc[merged_df['TEAM_ID'] == home_team_id, 'TEAM_PTS'].values[0]

    # Label as home or away
    merged_df['HOME'] = merged_df['TEAM_ID'] == home_team_id

    # Label as won or lost
    winning_team_id = home_team_id if home_score > away_score else away_team_id
    merged_df['WON'] = merged_df['TEAM_ID'] == winning_team_id

    # Add final score comparison
    merged_df['FINAL_SCORE'] = merged_df.apply(
        lambda row: [int(home_score), int(away_score)] if row['TEAM_ID'] == home_team_id else [int(away_score), int(home_score)],
        axis=1
    )

    # Add oponent team stats
    def get_opponent_team_id(team_id):
        return home_team_id if team_id == away_team_id else away_team_id

    merged_df['OPP_TEAM_ID'] = merged_df['TEAM_ID'].apply(get_opponent_team_id)
    merged_df = merged_df.merge(team_df_opp, on='OPP_TEAM_ID', how='left')

    return merged_df


def main(season):
    csv_path = f"data/nba_boxscores_{season}.csv"

    print("🔍 Checking existing data...")
    existing_game_ids = get_existing_game_ids(csv_path)

    print("📅 Getting game IDs + dates for seasons...")
    games_df = get_all_game_ids_and_dates(season)
    new_games = games_df[~games_df['GAME_ID'].isin(existing_game_ids)]
    new_games = new_games.reset_index(drop=True)

    print(f"🆕 Found {len(new_games)} new games to fetch.")

    for i, row in new_games.iterrows():
        game_id = row['GAME_ID']
        game_date = row['GAME_DATE']
        game_type = row['SEASON_TYPE']

        try:
            print(f"📦 Fetching box score for {game_id} ({game_date.date()}) [{i+1}/{len(new_games)}]")
            df = fetch_box_score(game_id)
            df['GAME_DATE'] = game_date
            df['SEASON_TYPE'] = game_type

            if os.path.exists(csv_path):
                df.to_csv(csv_path, mode='a', header=False, index=False)
            else:
                df.to_csv(csv_path, index=False)

            smart_sleep()
        except Exception as e:
            print(f"❌ Error fetching {game_id}: {e}")
            continue

# %%
main('2024-25')
# Out:
# 🔍 Checking existing data...
# 📅 Getting game IDs + dates for seasons...
# 📅 Fetching Regular Season logs for 2024-25
# 📅 Fetching Playoffs logs for 2024-25
# 🆕 Found 455 new games to fetch.
# 📦 Fetching box score for 0022400761 (2025-02-10) [1/455]
# 📦 Fetching box score for 0022400760 (2025-02-10) [2/455]
# 📦 Fetching box score for 0022400762 (2025-02-10) [3/455]
# 📦 Fetching box score for 0022400763 (2025-02-10) [4/455]
# 📦 Fetching box score for 0022400768 (2025-02-10) [5/455]
# 📦 Fetching box score for 0022400764 (2025-02-11) [6/455]
# 📦 Fetching box score for 0022400765 (2025-02-11) [7/455]
# 📦 Fetching box score for 0022400766 (2025-02-11) [8/455]
# 📦 Fetching box score for 0022400767 (2025-02-11) [9/455]
# 📦 Fetching box score for 0022400783 (2025-02-12) [10/455]
# 📦 Fetching box score for 0022400770 (2025-02-12) [11/455]
# 📦 Fetching box score for 0022400769 (2025-02-12) [12/455]
# 📦 Fetching box score for 0022400771 (2025-02-12) [13/455]
# 📦 Fetching box score for 0022400772 (2025-02-12) [14/455]
# 📦 Fetching box score for 0022400774 (2025-02-12) [15/455]
# 📦 Fetching box score for 0022400776 (2025-02-12) [16/455]
# 📦 Fetching box score for 0022400778 (2025-02-12) [17/455]
# 📦 Fetching box score for 0022400775 (2025-02-12) [18/455]
# 📦 Fetching box score for 0022400777 (2025-02-12) [19/455]
# 📦 Fetching box score for 0022400781 (2025-02-12) [20/455]
# 📦 Fetching box score for 0022400773 (2025-02-12) [21/455]
# 📦 Fetching box score for 0022400779 (2025-02-12) [22/455]
# 📦 Fetching box score for 0022400780 (2025-02-12) [23/455]
# 📦 Fetching box score for 0022400782 (2025-02-12) [24/455]
# 📦 Fetching box score for 0022401004 (2025-02-13) [25/455]
# 📦 Fetching box score for 0022400787 (2025-02-13) [26/455]
# 📦 Fetching box score for 0022400786 (2025-02-13) [27/455]
# 📦 Fetching box score for 0022400785 (2025-02-13) [28/455]
# 📦 Fetching box score for 0022400784 (2025-02-13) [29/455]
# 📦 Fetching box score for 0022400524 (2025-02-19) [30/455]
# 📦 Fetching box score for 0022400795 (2025-02-20) [31/455]
# 📦 Fetching box score for 0022400796 (2025-02-20) [32/455]
# 📦 Fetching box score for 0022400794 (2025-02-20) [33/455]
# 📦 Fetching box score for 0022400790 (2025-02-20) [34/455]
# 📦 Fetching box score for 0022400793 (2025-02-20) [35/455]
# 📦 Fetching box score for 0022400792 (2025-02-20) [36/455]
# 📦 Fetching box score for 0022400788 (2025-02-20) [37/455]
# 📦 Fetching box score for 0022400791 (2025-02-20) [38/455]
# 📦 Fetching box score for 0022400789 (2025-02-20) [39/455]
# 📦 Fetching box score for 0022400797 (2025-02-21) [40/455]
# 📦 Fetching box score for 0022400799 (2025-02-21) [41/455]
# 📦 Fetching box score for 0022400800 (2025-02-21) [42/455]
# 📦 Fetching box score for 0022400804 (2025-02-21) [43/455]
# 📦 Fetching box score for 0022400801 (2025-02-21) [44/455]
# 📦 Fetching box score for 0022400805 (2025-02-21) [45/455]
# 📦 Fetching box score for 0022400802 (2025-02-21) [46/455]
# 📦 Fetching box score for 0022400803 (2025-02-21) [47/455]
# 📦 Fetching box score for 0022400798 (2025-02-21) [48/455]
# 📦 Fetching box score for 0022400806 (2025-02-22) [49/455]
# 📦 Fetching box score for 0022400810 (2025-02-22) [50/455]
# 📦 Fetching box score for 0022400809 (2025-02-22) [51/455]
# 📦 Fetching box score for 0022400808 (2025-02-22) [52/455]
# 📦 Fetching box score for 0022400807 (2025-02-22) [53/455]
# 📦 Fetching box score for 0022400814 (2025-02-23) [54/455]
# 📦 Fetching box score for 0022400813 (2025-02-23) [55/455]
# 📦 Fetching box score for 0022400817 (2025-02-23) [56/455]
# 📦 Fetching box score for 0022400812 (2025-02-23) [57/455]
# 📦 Fetching box score for 0022400816 (2025-02-23) [58/455]
# 📦 Fetching box score for 0022400811 (2025-02-23) [59/455]
# 📦 Fetching box score for 0022400818 (2025-02-23) [60/455]
# 📦 Fetching box score for 0022400815 (2025-02-23) [61/455]
# 📦 Fetching box score for 0022400819 (2025-02-23) [62/455]
# 📦 Fetching box score for 0022400820 (2025-02-23) [63/455]
# 📦 Fetching box score for 0022400822 (2025-02-24) [64/455]
# 📦 Fetching box score for 0022400828 (2025-02-24) [65/455]
# 📦 Fetching box score for 0022400827 (2025-02-24) [66/455]
# 📦 Fetching box score for 0022400826 (2025-02-24) [67/455]
# 📦 Fetching box score for 0022400821 (2025-02-24) [68/455]
# 📦 Fetching box score for 0022400824 (2025-02-24) [69/455]
# 📦 Fetching box score for 0022400825 (2025-02-24) [70/455]
# 📦 Fetching box score for 0022400823 (2025-02-24) [71/455]
# 📦 Fetching box score for 0022400830 (2025-02-25) [72/455]
# 📦 Fetching box score for 0022400829 (2025-02-25) [73/455]
# 📦 Fetching box score for 0022400833 (2025-02-25) [74/455]
# 📦 Fetching box score for 0022400832 (2025-02-25) [75/455]
# 📦 Fetching box score for 0022400835 (2025-02-25) [76/455]
# 📦 Fetching box score for 0022400834 (2025-02-25) [77/455]
# 📦 Fetching box score for 0022400831 (2025-02-25) [78/455]
# 📦 Fetching box score for 0022400842 (2025-02-26) [79/455]
# 📦 Fetching box score for 0022400844 (2025-02-26) [80/455]
# 📦 Fetching box score for 0022400843 (2025-02-26) [81/455]
# 📦 Fetching box score for 0022400840 (2025-02-26) [82/455]
# 📦 Fetching box score for 0022400839 (2025-02-26) [83/455]
# 📦 Fetching box score for 0022400837 (2025-02-26) [84/455]
# 📦 Fetching box score for 0022400841 (2025-02-26) [85/455]
# 📦 Fetching box score for 0022400838 (2025-02-26) [86/455]
# 📦 Fetching box score for 0022400836 (2025-02-26) [87/455]
# 📦 Fetching box score for 0022400849 (2025-02-27) [88/455]
# 📦 Fetching box score for 0022400845 (2025-02-27) [89/455]
# 📦 Fetching box score for 0022400848 (2025-02-27) [90/455]
# 📦 Fetching box score for 0022400846 (2025-02-27) [91/455]
# 📦 Fetching box score for 0022400847 (2025-02-27) [92/455]
# 📦 Fetching box score for 0022400850 (2025-02-28) [93/455]
# 📦 Fetching box score for 0022400852 (2025-02-28) [94/455]
# 📦 Fetching box score for 0022400853 (2025-02-28) [95/455]
# 📦 Fetching box score for 0022400854 (2025-02-28) [96/455]
# 📦 Fetching box score for 0022400856 (2025-02-28) [97/455]
# 📦 Fetching box score for 0022400855 (2025-02-28) [98/455]
# 📦 Fetching box score for 0022400857 (2025-02-28) [99/455]
# 📦 Fetching box score for 0022400859 (2025-02-28) [100/455]
# 📦 Fetching box score for 0022400858 (2025-02-28) [101/455]
# 📦 Fetching box score for 0022400851 (2025-02-28) [102/455]
# 📦 Fetching box score for 0022400860 (2025-03-01) [103/455]
# 📦 Fetching box score for 0022400864 (2025-03-01) [104/455]
# 📦 Fetching box score for 0022400863 (2025-03-01) [105/455]
# 📦 Fetching box score for 0022400865 (2025-03-01) [106/455]
# 📦 Fetching box score for 0022400862 (2025-03-01) [107/455]
# 📦 Fetching box score for 0022400861 (2025-03-01) [108/455]
# 📦 Fetching box score for 0022400866 (2025-03-02) [109/455]
# 📦 Fetching box score for 0022400868 (2025-03-02) [110/455]
# 📦 Fetching box score for 0022400869 (2025-03-02) [111/455]
# 📦 Fetching box score for 0022400870 (2025-03-02) [112/455]
# 📦 Fetching box score for 0022400872 (2025-03-02) [113/455]
# 📦 Fetching box score for 0022400874 (2025-03-02) [114/455]
# 📦 Fetching box score for 0022400873 (2025-03-02) [115/455]
# 📦 Fetching box score for 0022400867 (2025-03-02) [116/455]
# 📦 Fetching box score for 0022400871 (2025-03-02) [117/455]
# 📦 Fetching box score for 0022400879 (2025-03-03) [118/455]
# 📦 Fetching box score for 0022400881 (2025-03-03) [119/455]
# 📦 Fetching box score for 0022400880 (2025-03-03) [120/455]
# 📦 Fetching box score for 0022400878 (2025-03-03) [121/455]
# 📦 Fetching box score for 0022400876 (2025-03-03) [122/455]
# 📦 Fetching box score for 0022400875 (2025-03-03) [123/455]
# 📦 Fetching box score for 0022400877 (2025-03-03) [124/455]
# 📦 Fetching box score for 0022400888 (2025-03-04) [125/455]
# 📦 Fetching box score for 0022400885 (2025-03-04) [126/455]
# 📦 Fetching box score for 0022400886 (2025-03-04) [127/455]
# 📦 Fetching box score for 0022400884 (2025-03-04) [128/455]
# 📦 Fetching box score for 0022400887 (2025-03-04) [129/455]
# 📦 Fetching box score for 0022400890 (2025-03-04) [130/455]
# 📦 Fetching box score for 0022400883 (2025-03-04) [131/455]
# 📦 Fetching box score for 0022400882 (2025-03-04) [132/455]
# 📦 Fetching box score for 0022400889 (2025-03-04) [133/455]
# 📦 Fetching box score for 0022400898 (2025-03-05) [134/455]
# 📦 Fetching box score for 0022400895 (2025-03-05) [135/455]
# 📦 Fetching box score for 0022400893 (2025-03-05) [136/455]
# 📦 Fetching box score for 0022400897 (2025-03-05) [137/455]
# 📦 Fetching box score for 0022400892 (2025-03-05) [138/455]
# 📦 Fetching box score for 0022400891 (2025-03-05) [139/455]
# 📦 Fetching box score for 0022400894 (2025-03-05) [140/455]
# 📦 Fetching box score for 0022400896 (2025-03-05) [141/455]
# 📦 Fetching box score for 0022400903 (2025-03-06) [142/455]
# 📦 Fetching box score for 0022400900 (2025-03-06) [143/455]
# 📦 Fetching box score for 0022400902 (2025-03-06) [144/455]
# 📦 Fetching box score for 0022400899 (2025-03-06) [145/455]
# 📦 Fetching box score for 0022400901 (2025-03-06) [146/455]
# 📦 Fetching box score for 0022400944 (2025-03-06) [147/455]
# 📦 Fetching box score for 0022400905 (2025-03-07) [148/455]
# 📦 Fetching box score for 0022400906 (2025-03-07) [149/455]
# 📦 Fetching box score for 0022400904 (2025-03-07) [150/455]
# 📦 Fetching box score for 0022400908 (2025-03-07) [151/455]
# 📦 Fetching box score for 0022400910 (2025-03-07) [152/455]
# 📦 Fetching box score for 0022400909 (2025-03-07) [153/455]
# 📦 Fetching box score for 0022400911 (2025-03-07) [154/455]
# 📦 Fetching box score for 0022400907 (2025-03-07) [155/455]
# 📦 Fetching box score for 0022400919 (2025-03-08) [156/455]
# 📦 Fetching box score for 0022400912 (2025-03-08) [157/455]
# 📦 Fetching box score for 0022400914 (2025-03-08) [158/455]
# 📦 Fetching box score for 0022400916 (2025-03-08) [159/455]
# 📦 Fetching box score for 0022400918 (2025-03-08) [160/455]
# 📦 Fetching box score for 0022400917 (2025-03-08) [161/455]
# 📦 Fetching box score for 0022400913 (2025-03-08) [162/455]
# 📦 Fetching box score for 0022400915 (2025-03-08) [163/455]
# 📦 Fetching box score for 0022400921 (2025-03-09) [164/455]
# 📦 Fetching box score for 0022400923 (2025-03-09) [165/455]
# 📦 Fetching box score for 0022400925 (2025-03-09) [166/455]
# 📦 Fetching box score for 0022400920 (2025-03-09) [167/455]
# 📦 Fetching box score for 0022400924 (2025-03-09) [168/455]
# 📦 Fetching box score for 0022400922 (2025-03-09) [169/455]
# 📦 Fetching box score for 0022400926 (2025-03-09) [170/455]
# 📦 Fetching box score for 0022400927 (2025-03-09) [171/455]
# 📦 Fetching box score for 0022400938 (2025-03-10) [172/455]
# 📦 Fetching box score for 0022400936 (2025-03-10) [173/455]
# 📦 Fetching box score for 0022400934 (2025-03-10) [174/455]
# 📦 Fetching box score for 0022400935 (2025-03-10) [175/455]
# 📦 Fetching box score for 0022400937 (2025-03-10) [176/455]
# 📦 Fetching box score for 0022400929 (2025-03-10) [177/455]
# 📦 Fetching box score for 0022400930 (2025-03-10) [178/455]
# 📦 Fetching box score for 0022400933 (2025-03-10) [179/455]
# 📦 Fetching box score for 0022400939 (2025-03-10) [180/455]
# 📦 Fetching box score for 0022400928 (2025-03-10) [181/455]
# 📦 Fetching box score for 0022400932 (2025-03-10) [182/455]
# 📦 Fetching box score for 0022400931 (2025-03-10) [183/455]
# 📦 Fetching box score for 0022400943 (2025-03-11) [184/455]
# 📦 Fetching box score for 0022400940 (2025-03-11) [185/455]
# 📦 Fetching box score for 0022400941 (2025-03-11) [186/455]
# 📦 Fetching box score for 0022400942 (2025-03-11) [187/455]
# 📦 Fetching box score for 0022400953 (2025-03-12) [188/455]
# 📦 Fetching box score for 0022400952 (2025-03-12) [189/455]
# 📦 Fetching box score for 0022400949 (2025-03-12) [190/455]
# 📦 Fetching box score for 0022400945 (2025-03-12) [191/455]
# 📦 Fetching box score for 0022400947 (2025-03-12) [192/455]
# 📦 Fetching box score for 0022400948 (2025-03-12) [193/455]
# 📦 Fetching box score for 0022400950 (2025-03-12) [194/455]
# 📦 Fetching box score for 0022400951 (2025-03-12) [195/455]
# 📦 Fetching box score for 0022400946 (2025-03-12) [196/455]
# 📦 Fetching box score for 0022400955 (2025-03-13) [197/455]
# 📦 Fetching box score for 0022400956 (2025-03-13) [198/455]
# 📦 Fetching box score for 0022400954 (2025-03-13) [199/455]
# 📦 Fetching box score for 0022401141 (2025-03-13) [200/455]
# 📦 Fetching box score for 0022400957 (2025-03-13) [201/455]
# 📦 Fetching box score for 0022400966 (2025-03-14) [202/455]
# 📦 Fetching box score for 0022400967 (2025-03-14) [203/455]
# 📦 Fetching box score for 0022400958 (2025-03-14) [204/455]
# 📦 Fetching box score for 0022400959 (2025-03-14) [205/455]
# 📦 Fetching box score for 0022400960 (2025-03-14) [206/455]
# 📦 Fetching box score for 0022400961 (2025-03-14) [207/455]
# 📦 Fetching box score for 0022400964 (2025-03-14) [208/455]
# 📦 Fetching box score for 0022400962 (2025-03-14) [209/455]
# 📦 Fetching box score for 0022400963 (2025-03-14) [210/455]
# 📦 Fetching box score for 0022400965 (2025-03-14) [211/455]
# 📦 Fetching box score for 0022400972 (2025-03-15) [212/455]
# 📦 Fetching box score for 0022400968 (2025-03-15) [213/455]
# 📦 Fetching box score for 0022400973 (2025-03-15) [214/455]
# 📦 Fetching box score for 0022400974 (2025-03-15) [215/455]
# 📦 Fetching box score for 0022400975 (2025-03-15) [216/455]
# 📦 Fetching box score for 0022400970 (2025-03-15) [217/455]
# 📦 Fetching box score for 0022400969 (2025-03-15) [218/455]
# 📦 Fetching box score for 0022400971 (2025-03-15) [219/455]
# 📦 Fetching box score for 0022400981 (2025-03-16) [220/455]
# 📦 Fetching box score for 0022400538 (2025-03-16) [221/455]
# 📦 Fetching box score for 0022400977 (2025-03-16) [222/455]
# 📦 Fetching box score for 0022400982 (2025-03-16) [223/455]
# 📦 Fetching box score for 0022400979 (2025-03-16) [224/455]
# 📦 Fetching box score for 0022400980 (2025-03-16) [225/455]
# 📦 Fetching box score for 0022400976 (2025-03-16) [226/455]
# 📦 Fetching box score for 0022400978 (2025-03-16) [227/455]
# 📦 Fetching box score for 0022400987 (2025-03-17) [228/455]
# 📦 Fetching box score for 0022400991 (2025-03-17) [229/455]
# 📦 Fetching box score for 0022400995 (2025-03-17) [230/455]
# 📦 Fetching box score for 0022400989 (2025-03-17) [231/455]
# 📦 Fetching box score for 0022400986 (2025-03-17) [232/455]
# 📦 Fetching box score for 0022400537 (2025-03-17) [233/455]
# 📦 Fetching box score for 0022400990 (2025-03-17) [234/455]
# 📦 Fetching box score for 0022400985 (2025-03-17) [235/455]
# 📦 Fetching box score for 0022400984 (2025-03-17) [236/455]
# 📦 Fetching box score for 0022400992 (2025-03-17) [237/455]
# 📦 Fetching box score for 0022400997 (2025-03-18) [238/455]
# 📦 Fetching box score for 0022401012 (2025-03-18) [239/455]
# 📦 Fetching box score for 0022400994 (2025-03-18) [240/455]
# 📦 Fetching box score for 0022400993 (2025-03-18) [241/455]
# 📦 Fetching box score for 0022400999 (2025-03-19) [242/455]
# 📦 Fetching box score for 0022400998 (2025-03-19) [243/455]
# 📦 Fetching box score for 0022401002 (2025-03-19) [244/455]
# 📦 Fetching box score for 0022401001 (2025-03-19) [245/455]
# 📦 Fetching box score for 0022400627 (2025-03-19) [246/455]
# 📦 Fetching box score for 0022401000 (2025-03-19) [247/455]
# 📦 Fetching box score for 0022401003 (2025-03-19) [248/455]
# 📦 Fetching box score for 0022401006 (2025-03-19) [249/455]
# 📦 Fetching box score for 0022401007 (2025-03-19) [250/455]
# 📦 Fetching box score for 0022401008 (2025-03-19) [251/455]
# 📦 Fetching box score for 0022401009 (2025-03-19) [252/455]
# 📦 Fetching box score for 0022401011 (2025-03-20) [253/455]
# 📦 Fetching box score for 0022401010 (2025-03-20) [254/455]
# 📦 Fetching box score for 0022400996 (2025-03-20) [255/455]
# 📦 Fetching box score for 0022401005 (2025-03-20) [256/455]
# 📦 Fetching box score for 0022401013 (2025-03-20) [257/455]
# 📦 Fetching box score for 0022401015 (2025-03-21) [258/455]
# 📦 Fetching box score for 0022401023 (2025-03-21) [259/455]
# 📦 Fetching box score for 0022401022 (2025-03-21) [260/455]
# 📦 Fetching box score for 0022401021 (2025-03-21) [261/455]
# 📦 Fetching box score for 0022401018 (2025-03-21) [262/455]
# 📦 Fetching box score for 0022401016 (2025-03-21) [263/455]
# 📦 Fetching box score for 0022401017 (2025-03-21) [264/455]
# 📦 Fetching box score for 0022401020 (2025-03-21) [265/455]
# 📦 Fetching box score for 0022401019 (2025-03-21) [266/455]
# 📦 Fetching box score for 0022401014 (2025-03-21) [267/455]
# 📦 Fetching box score for 0022401024 (2025-03-22) [268/455]
# 📦 Fetching box score for 0022401028 (2025-03-22) [269/455]
# 📦 Fetching box score for 0022401025 (2025-03-22) [270/455]
# 📦 Fetching box score for 0022401027 (2025-03-22) [271/455]
# 📦 Fetching box score for 0022401026 (2025-03-22) [272/455]
# 📦 Fetching box score for 0022401035 (2025-03-23) [273/455]
# 📦 Fetching box score for 0022401036 (2025-03-23) [274/455]
# 📦 Fetching box score for 0022401032 (2025-03-23) [275/455]
# 📦 Fetching box score for 0022401034 (2025-03-23) [276/455]
# 📦 Fetching box score for 0022401031 (2025-03-23) [277/455]
# 📦 Fetching box score for 0022401029 (2025-03-23) [278/455]
# 📦 Fetching box score for 0022401030 (2025-03-23) [279/455]
# 📦 Fetching box score for 0022401033 (2025-03-23) [280/455]
# 📦 Fetching box score for 0022401043 (2025-03-24) [281/455]
# 📦 Fetching box score for 0022401041 (2025-03-24) [282/455]
# 📦 Fetching box score for 0022401038 (2025-03-24) [283/455]
# 📦 Fetching box score for 0022401044 (2025-03-24) [284/455]
# 📦 Fetching box score for 0022401040 (2025-03-24) [285/455]
# 📦 Fetching box score for 0022401037 (2025-03-24) [286/455]
# 📦 Fetching box score for 0022401039 (2025-03-24) [287/455]
# 📦 Fetching box score for 0022401042 (2025-03-24) [288/455]
# 📦 Fetching box score for 0022401052 (2025-03-25) [289/455]
# 📦 Fetching box score for 0022401048 (2025-03-25) [290/455]
# 📦 Fetching box score for 0022401046 (2025-03-25) [291/455]
# 📦 Fetching box score for 0022401045 (2025-03-25) [292/455]
# 📦 Fetching box score for 0022401047 (2025-03-25) [293/455]
# 📦 Fetching box score for 0022401051 (2025-03-25) [294/455]
# 📦 Fetching box score for 0022401050 (2025-03-25) [295/455]
# 📦 Fetching box score for 0022401049 (2025-03-25) [296/455]
# 📦 Fetching box score for 0022401058 (2025-03-26) [297/455]
# 📦 Fetching box score for 0022401055 (2025-03-26) [298/455]
# 📦 Fetching box score for 0022401057 (2025-03-26) [299/455]
# 📦 Fetching box score for 0022401054 (2025-03-26) [300/455]
# 📦 Fetching box score for 0022401053 (2025-03-26) [301/455]
# 📦 Fetching box score for 0022401056 (2025-03-26) [302/455]
# 📦 Fetching box score for 0022401066 (2025-03-27) [303/455]
# 📦 Fetching box score for 0022401061 (2025-03-27) [304/455]
# 📦 Fetching box score for 0022401059 (2025-03-27) [305/455]
# 📦 Fetching box score for 0022401062 (2025-03-27) [306/455]
# 📦 Fetching box score for 0022401064 (2025-03-27) [307/455]
# 📦 Fetching box score for 0022401063 (2025-03-27) [308/455]
# 📦 Fetching box score for 0022401060 (2025-03-27) [309/455]
# 📦 Fetching box score for 0022401065 (2025-03-27) [310/455]
# 📦 Fetching box score for 0022401073 (2025-03-28) [311/455]
# 📦 Fetching box score for 0022401067 (2025-03-28) [312/455]
# 📦 Fetching box score for 0022401069 (2025-03-28) [313/455]
# 📦 Fetching box score for 0022401068 (2025-03-28) [314/455]
# 📦 Fetching box score for 0022401071 (2025-03-28) [315/455]
# 📦 Fetching box score for 0022401072 (2025-03-28) [316/455]
# 📦 Fetching box score for 0022401070 (2025-03-28) [317/455]
# 📦 Fetching box score for 0022401080 (2025-03-29) [318/455]
# 📦 Fetching box score for 0022401074 (2025-03-29) [319/455]
# 📦 Fetching box score for 0022401075 (2025-03-29) [320/455]
# 📦 Fetching box score for 0022401076 (2025-03-29) [321/455]
# 📦 Fetching box score for 0022401079 (2025-03-29) [322/455]
# 📦 Fetching box score for 0022401077 (2025-03-29) [323/455]
# 📦 Fetching box score for 0022401078 (2025-03-29) [324/455]
# 📦 Fetching box score for 0022401081 (2025-03-30) [325/455]
# 📦 Fetching box score for 0022401088 (2025-03-30) [326/455]
# 📦 Fetching box score for 0022401086 (2025-03-30) [327/455]
# 📦 Fetching box score for 0022401087 (2025-03-30) [328/455]
# 📦 Fetching box score for 0022401083 (2025-03-30) [329/455]
# 📦 Fetching box score for 0022401085 (2025-03-30) [330/455]
# 📦 Fetching box score for 0022401084 (2025-03-30) [331/455]
# 📦 Fetching box score for 0022401082 (2025-03-30) [332/455]
# 📦 Fetching box score for 0022401095 (2025-03-31) [333/455]
# 📦 Fetching box score for 0022401092 (2025-03-31) [334/455]
# 📦 Fetching box score for 0022401091 (2025-03-31) [335/455]
# 📦 Fetching box score for 0022401093 (2025-03-31) [336/455]
# 📦 Fetching box score for 0022401096 (2025-03-31) [337/455]
# 📦 Fetching box score for 0022401094 (2025-03-31) [338/455]
# 📦 Fetching box score for 0022401089 (2025-03-31) [339/455]
# 📦 Fetching box score for 0022401090 (2025-03-31) [340/455]
# 📦 Fetching box score for 0022401101 (2025-04-01) [341/455]
# 📦 Fetching box score for 0022401100 (2025-04-01) [342/455]
# 📦 Fetching box score for 0022400988 (2025-04-01) [343/455]
# 📦 Fetching box score for 0022401102 (2025-04-01) [344/455]
# 📦 Fetching box score for 0022401099 (2025-04-01) [345/455]
# 📦 Fetching box score for 0022401098 (2025-04-01) [346/455]
# 📦 Fetching box score for 0022401097 (2025-04-01) [347/455]
# 📦 Fetching box score for 0022401108 (2025-04-02) [348/455]
# 📦 Fetching box score for 0022401111 (2025-04-02) [349/455]
# 📦 Fetching box score for 0022401110 (2025-04-02) [350/455]
# 📦 Fetching box score for 0022401109 (2025-04-02) [351/455]
# 📦 Fetching box score for 0022401105 (2025-04-02) [352/455]
# 📦 Fetching box score for 0022401107 (2025-04-02) [353/455]
# 📦 Fetching box score for 0022401106 (2025-04-02) [354/455]
# 📦 Fetching box score for 0022401103 (2025-04-02) [355/455]
# 📦 Fetching box score for 0022401104 (2025-04-02) [356/455]
# 📦 Fetching box score for 0022401115 (2025-04-03) [357/455]
# 📦 Fetching box score for 0022401112 (2025-04-03) [358/455]
# 📦 Fetching box score for 0022401116 (2025-04-03) [359/455]
# 📦 Fetching box score for 0022401113 (2025-04-03) [360/455]
# 📦 Fetching box score for 0022401114 (2025-04-03) [361/455]
# 📦 Fetching box score for 0022401117 (2025-04-03) [362/455]
# 📦 Fetching box score for 0022401125 (2025-04-04) [363/455]
# 📦 Fetching box score for 0022401118 (2025-04-04) [364/455]
# 📦 Fetching box score for 0022401120 (2025-04-04) [365/455]
# 📦 Fetching box score for 0022401123 (2025-04-04) [366/455]
# 📦 Fetching box score for 0022401121 (2025-04-04) [367/455]
# 📦 Fetching box score for 0022401119 (2025-04-04) [368/455]
# 📦 Fetching box score for 0022401122 (2025-04-04) [369/455]
# 📦 Fetching box score for 0022401124 (2025-04-04) [370/455]
# 📦 Fetching box score for 0022401127 (2025-04-04) [371/455]
# 📦 Fetching box score for 0022401126 (2025-04-04) [372/455]
# 📦 Fetching box score for 0022401130 (2025-04-05) [373/455]
# 📦 Fetching box score for 0022401132 (2025-04-05) [374/455]
# 📦 Fetching box score for 0022401131 (2025-04-05) [375/455]
# 📦 Fetching box score for 0022401129 (2025-04-05) [376/455]
# 📦 Fetching box score for 0022401128 (2025-04-05) [377/455]
# 📦 Fetching box score for 0022401143 (2025-04-06) [378/455]
# 📦 Fetching box score for 0022401138 (2025-04-06) [379/455]
# 📦 Fetching box score for 0022401137 (2025-04-06) [380/455]
# 📦 Fetching box score for 0022401134 (2025-04-06) [381/455]
# 📦 Fetching box score for 0022401135 (2025-04-06) [382/455]
# 📦 Fetching box score for 0022401136 (2025-04-06) [383/455]
# 📦 Fetching box score for 0022401139 (2025-04-06) [384/455]
# 📦 Fetching box score for 0022400617 (2025-04-06) [385/455]
# 📦 Fetching box score for 0022401142 (2025-04-06) [386/455]
# 📦 Fetching box score for 0022401140 (2025-04-06) [387/455]
# 📦 Fetching box score for 0022401133 (2025-04-06) [388/455]
# 📦 Fetching box score for 0022401145 (2025-04-07) [389/455]
# 📦 Fetching box score for 0022401144 (2025-04-07) [390/455]
# 📦 Fetching box score for 0022401150 (2025-04-08) [391/455]
# 📦 Fetching box score for 0022401155 (2025-04-08) [392/455]
# 📦 Fetching box score for 0022401151 (2025-04-08) [393/455]
# 📦 Fetching box score for 0022401152 (2025-04-08) [394/455]
# 📦 Fetching box score for 0022401153 (2025-04-08) [395/455]
# 📦 Fetching box score for 0022401148 (2025-04-08) [396/455]
# 📦 Fetching box score for 0022401147 (2025-04-08) [397/455]
# 📦 Fetching box score for 0022401146 (2025-04-08) [398/455]
# 📦 Fetching box score for 0022401149 (2025-04-08) [399/455]
# 📦 Fetching box score for 0022401154 (2025-04-08) [400/455]
# 📦 Fetching box score for 0022401156 (2025-04-09) [401/455]
# 📦 Fetching box score for 0022401159 (2025-04-09) [402/455]
# 📦 Fetching box score for 0022401165 (2025-04-09) [403/455]
# 📦 Fetching box score for 0022401160 (2025-04-09) [404/455]
# 📦 Fetching box score for 0022401157 (2025-04-09) [405/455]
# 📦 Fetching box score for 0022401158 (2025-04-09) [406/455]
# 📦 Fetching box score for 0022401162 (2025-04-09) [407/455]
# 📦 Fetching box score for 0022401164 (2025-04-09) [408/455]
# 📦 Fetching box score for 0022401163 (2025-04-09) [409/455]
# 📦 Fetching box score for 0022401166 (2025-04-09) [410/455]
# 📦 Fetching box score for 0022401161 (2025-04-10) [411/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401161
# ❌ Error fetching 0022401161: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401170 (2025-04-10) [412/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401170
# ❌ Error fetching 0022401170: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401168 (2025-04-10) [413/455]
# ❌ Error fetching 0022401168: cannot convert float NaN to integer
# 📦 Fetching box score for 0022401169 (2025-04-10) [414/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401169
# ❌ Error fetching 0022401169: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401167 (2025-04-10) [415/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401167
# ❌ Error fetching 0022401167: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401180 (2025-04-11) [416/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401180
# ❌ Error fetching 0022401180: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401179 (2025-04-11) [417/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401179
# ❌ Error fetching 0022401179: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401176 (2025-04-11) [418/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401176
# ❌ Error fetching 0022401176: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401175 (2025-04-11) [419/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401175
# ❌ Error fetching 0022401175: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401172 (2025-04-11) [420/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401172
# ❌ Error fetching 0022401172: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401178 (2025-04-11) [421/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401178
# ❌ Error fetching 0022401178: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401177 (2025-04-11) [422/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401177
# ❌ Error fetching 0022401177: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401174 (2025-04-11) [423/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401174
# ❌ Error fetching 0022401174: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401171 (2025-04-11) [424/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401171
# ❌ Error fetching 0022401171: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401173 (2025-04-11) [425/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401173
# ❌ Error fetching 0022401173: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401181 (2025-04-11) [426/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401181
# ❌ Error fetching 0022401181: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401182 (2025-04-11) [427/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401182
# ❌ Error fetching 0022401182: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401185 (2025-04-11) [428/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401185
# ❌ Error fetching 0022401185: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401184 (2025-04-11) [429/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401184
# ❌ Error fetching 0022401184: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401183 (2025-04-11) [430/455]
# ❌ Error fetching 0022401183: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# 📦 Fetching box score for 0022401189 (2025-04-13) [431/455]
# ❌ Error fetching 0022401189: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# 📦 Fetching box score for 0022401188 (2025-04-13) [432/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401188
# ❌ Error fetching 0022401188: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401187 (2025-04-13) [433/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401187
# ❌ Error fetching 0022401187: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401190 (2025-04-13) [434/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401190
# ❌ Error fetching 0022401190: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401191 (2025-04-13) [435/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401191
# ❌ Error fetching 0022401191: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401186 (2025-04-13) [436/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401186
# ❌ Error fetching 0022401186: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401192 (2025-04-13) [437/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401192
# ❌ Error fetching 0022401192: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401193 (2025-04-13) [438/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401193
# ❌ Error fetching 0022401193: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401194 (2025-04-13) [439/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401194
# ❌ Error fetching 0022401194: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401200 (2025-04-13) [440/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401200
# ❌ Error fetching 0022401200: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401199 (2025-04-13) [441/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401199
# ❌ Error fetching 0022401199: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401197 (2025-04-13) [442/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401197
# ❌ Error fetching 0022401197: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401196 (2025-04-13) [443/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401196
# ❌ Error fetching 0022401196: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401195 (2025-04-13) [444/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401195
# ❌ Error fetching 0022401195: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0022401198 (2025-04-13) [445/455]
# ⚠️ Unexpected number of teams in GAME_ID 0022401198
# ❌ Error fetching 0022401198: 'NoneType' object does not support item assignment
# 📦 Fetching box score for 0042400131 (2025-04-19) [446/455]
# 📦 Fetching box score for 0042400171 (2025-04-19) [447/455]
# 📦 Fetching box score for 0042400161 (2025-04-19) [448/455]
# 📦 Fetching box score for 0042400121 (2025-04-19) [449/455]
# 📦 Fetching box score for 0042400141 (2025-04-20) [450/455]
# 📦 Fetching box score for 0042400111 (2025-04-20) [451/455]
# 📦 Fetching box score for 0042400101 (2025-04-20) [452/455]
# 📦 Fetching box score for 0042400151 (2025-04-20) [453/455]
# 📦 Fetching box score for 0042400122 (2025-04-21) [454/455]
# 📦 Fetching box score for 0042400172 (2025-04-21) [455/455]
